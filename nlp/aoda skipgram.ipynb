# %%
from collections import Counter
import statistics
import pickle

# %%
import numpy as np
import pandas as pd
import tensorflow.keras as keras

# %%
np.set_printoptions(suppress=True)

# %% [markdown]
# # load data

# %%
laws = pickle.load(open('./data/law_objects.p', 'rb'))
aoda = laws['Accessibility for Ontarians with Disabilities Act, 2005, S.O. 2005, c. 11']

# %%
# load the table of contents...
# df_toc = pd.DataFrame(aoda.table_of_content.values())
# df_toc

# %% [markdown]
# ## make training data for model

# %%
def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
full_text = aoda.get_full_text().split()

# %%
vocab_size = 1000

# %%
data, count, dictionary, reversed_dictionary = build_dataset(full_text, vocab_size)

# %%
sampling_table = keras.preprocessing.sequence.make_sampling_table(vocab_size)

# %%
window_size = 3

# %%
couples, labels = keras.preprocessing.sequence.skipgrams(data, vocab_size, window_size=window_size, sampling_table=sampling_table)

# %%
word_target, word_context = zip(*couples)
word_target = np.array(word_target, dtype="int32")
word_context = np.array(word_context, dtype="int32")

# %% [markdown]
# # define model

# %%
vector_dim = 50

# %%
input_target = keras.Input((1,))
input_context = keras.Input((1,))

embedding = keras.layers.Embedding(vocab_size, vector_dim, input_length=1, name='embedding')

# %%
target = embedding(input_target)

# %%
target.shape
# Out:
# TensorShape([None, 1, 50])

# %%
target = keras.layers.Reshape((vector_dim, 1))(target)

# %%
target.shape
# Out:
# TensorShape([None, 50, 1])

# %%
context = embedding(input_context)
context = keras.layers.Reshape((vector_dim, 1))(context)

# %%
context.shape
# Out:
# TensorShape([None, 50, 1])

# %%
# keras.layers.Dot?

# %%
# now perform the dot product operation to get a similarity measure
dot_product = keras.layers.Dot(axes=(1, 1))([target, context])
dot_product = keras.layers.Reshape((1,))(dot_product)
# add the sigmoid output layer
output = keras.layers.Dense(1, activation='sigmoid')(dot_product)

# %%
dot_product.shape
# Out:
# TensorShape([None, 1])

# %%
# keras.models.Model?

# %%
model = keras.models.Model(inputs=[input_target, input_context], outputs=output)
model.compile(loss='binary_crossentropy', optimizer='rmsprop')

# %% [markdown]
# # inspect embedding

# %%
w = embedding.get_weights()[0]

# %%
idx = dictionary['person']

# %%
w[idx]
# Out:
# array([ 0.02925575, -0.01843834,  0.03733312, -0.0313976 , -0.01940695,
#         0.01041225,  0.00201752,  0.02015884,  0.0386101 ,  0.00533808,
#         0.03039486, -0.00579585,  0.033606  , -0.01014917,  0.04261595,
#         0.04498413, -0.04882659,  0.02630835,  0.01966413,  0.04584287,
#         0.00514659, -0.04451193, -0.04878862, -0.02215931, -0.01911682,
#        -0.0174652 ,  0.0365127 ,  0.04618626,  0.00439218,  0.01646158,
#         0.04733505, -0.00554984, -0.00264033,  0.01767657, -0.02857149,
#         0.01559896, -0.02571657, -0.02604746, -0.0153017 ,  0.0063947 ,
#        -0.00148872, -0.01271559, -0.02182945,  0.033891  , -0.01929326,
#         0.00202904,  0.04824536, -0.01251889, -0.00886708, -0.02695013],
#       dtype=float32)

# %%
w[idx].shape
# Out:
# (50,)

# %% [markdown]
# ## query nearest neighbors in embedding space

# %%
from sklearn.neighbors import KNeighborsTransformer

# %%
knn = KNeighborsTransformer(n_neighbors=1, metric='cosine')

# %%
knn.fit(w)
# Out:
# KNeighborsTransformer(algorithm='auto', leaf_size=30, metric='cosine',
#                       metric_params=None, mode='distance', n_jobs=1,
#                       n_neighbors=1, p=2)

# %%
# knn.kneighbors?

neigh_dist, neigh_ind = knn.kneighbors(w[idx].reshape(1, -1), n_neighbors=5)

print(neigh_dist[0])
print(neigh_ind[0])
print(list(reversed_dictionary[i] for i in neigh_ind[0]))
# Out:
# [0.00000006 0.59828985 0.6276052  0.6665269  0.67346984]
# [ 10 193 646 531 474]
# ['person', 'set', 'known', 'associated', 'Executive']

# %%
def query_neighbors_in_embedding(w, words, n_neighbors=5):
    knn = KNeighborsTransformer(n_neighbors=1, metric='cosine')
    knn.fit(w)
    idx = [dictionary[word] for word in words]
    neigh_dist, neigh_ind = knn.kneighbors(w[(idx,)], n_neighbors + 1)
    # omit the first neighbor, which is always word the word being queried
    neigh_dist, neigh_ind = neigh_dist[:, 1:] , neigh_ind[:, 1:]
    results = {
        word: {
            reversed_dictionary[neighbor_ind]: float(neigh_dist[ith_word][k])
            for k, neighbor_ind in enumerate(neigh_ind[ith_word])
        }
        for ith_word, word in enumerate(words)
    }
    return results

# %%
query_results = query_neighbors_in_embedding(
    w,
    ['person', 'accessibility', 'organization', 'penalty'],
    n_neighbors=4)

print(json.dumps(query_results, indent=2))
# Out:
# {
#   "person": {
#     "set": 0.5982899069786072,
#     "known": 0.6276051998138428,
#     "associated": 0.6665268540382385,
#     "Executive": 0.6734698414802551
#   },
#   "accessibility": {
#     "25": 0.5333746671676636,
#     "employment,": 0.5708682537078857,
#     "range": 0.5768356323242188,
#     "proposed": 0.5900076627731323
#   },
#   "organization": {
#     "made": 0.5606701374053955,
#     "duties": 0.575109601020813,
#     "enforcement": 0.5856479406356812,
#     "developed": 0.6025199890136719
#   },
#   "penalty": {
#     "birth": 0.5703414678573608,
#     "accessible": 0.5717199444770813,
#     "disabilities;": 0.6037174463272095,
#     "peace": 0.6188006401062012
#   }
# }

# %% [markdown]
# # training

# %%
arr_1 = np.zeros((1,))
arr_2 = np.zeros((1,))
arr_3 = np.zeros((1,))


def train_on_idx(idx):
    arr_1[0,] = word_target[idx]
    arr_2[0,] = word_context[idx]
    arr_3[0,] = labels[idx]
    loss = model.train_on_batch([arr_1, arr_2], arr_3)
    return loss


def explain_some_neighbors():
    queries = query_neighbors_in_embedding(
        w=embedding.get_weights()[0],
        words=['person', 'accessibility', 'organization', 'penalty'],
        n_neighbors=3)
    print(json.dumps(queries, indent=4))
    return


losses_cache = list()


for epoch in range(10):
    for i, _ in enumerate(labels):
        idx = np.random.randint(0, len(labels)-1)
        loss = train_on_idx(idx)
        losses_cache.append(loss)
        if i % 500 == 0:
            losses_mean = statistics.mean(losses_cache)
            losses_cache = list()
            print(f"epoch={epoch:0>2d}, iteration={i:0>5d}, "
                  f"loss={loss:0>6f}, loss_mean={losses_mean:0>6f}")
    explain_some_neighbors()
# Out:
# epoch=00, iteration=00000, loss=0.699358, loss_mean=0.699358
# epoch=00, iteration=00500, loss=0.682558, loss_mean=0.692870
# epoch=00, iteration=01000, loss=0.699007, loss_mean=0.693242
# epoch=00, iteration=01500, loss=0.691583, loss_mean=0.692570
# epoch=00, iteration=02000, loss=0.689981, loss_mean=0.692101
# epoch=00, iteration=02500, loss=0.692204, loss_mean=0.691132
# epoch=00, iteration=03000, loss=0.681342, loss_mean=0.690656
# epoch=00, iteration=03500, loss=0.691498, loss_mean=0.688725
# epoch=00, iteration=04000, loss=0.676547, loss_mean=0.687493
# epoch=00, iteration=04500, loss=0.703089, loss_mean=0.687249
# epoch=00, iteration=05000, loss=0.681695, loss_mean=0.684497
# epoch=00, iteration=05500, loss=0.682064, loss_mean=0.681166
# epoch=00, iteration=06000, loss=0.684586, loss_mean=0.680693
# {
#     "person": {
#         "assistance": 0.5661463141441345,
#         "considers": 0.6121605038642883,
#         "practice;": 0.6200937032699585
#     },
#     "accessibility": {
#         "otherwise": 0.5800734162330627,
#         "$50,000": 0.6230185031890869,
#         "may,": 0.6414454579353333
#     },
#     "organization": {
#         "Before": 0.4194345474243164,
#         "enforcement": 0.5258558988571167,
#         "classes": 0.590445876121521
#     },
#     "penalty": {
#         "occupant.": 0.3895588517189026,
#         "fails": 0.4162708520889282,
#         "reference,": 0.45745497941970825
#     }
# }
# epoch=01, iteration=00000, loss=0.714663, loss_mean=0.676428
# epoch=01, iteration=00500, loss=0.617738, loss_mean=0.677568
# epoch=01, iteration=01000, loss=0.662586, loss_mean=0.672791
# epoch=01, iteration=01500, loss=0.698147, loss_mean=0.667259
# epoch=01, iteration=02000, loss=0.691466, loss_mean=0.664957
# epoch=01, iteration=02500, loss=0.672007, loss_mean=0.658939
# epoch=01, iteration=03000, loss=0.628971, loss_mean=0.648480
# epoch=01, iteration=03500, loss=0.693048, loss_mean=0.644839
# epoch=01, iteration=04000, loss=0.639203, loss_mean=0.638534
# epoch=01, iteration=04500, loss=0.643118, loss_mean=0.637060
# epoch=01, iteration=05000, loss=0.690031, loss_mean=0.622662
# epoch=01, iteration=05500, loss=0.657685, loss_mean=0.618976
# epoch=01, iteration=06000, loss=0.651034, loss_mean=0.611934
# {
#     "person": {
#         "assistance": 0.548478364944458,
#         "considers": 0.581288754940033,
#         "public": 0.6203558444976807
#     },
#     "accessibility": {
#         "otherwise": 0.5700504183769226,
#         "may,": 0.6229923963546753,
#         "considerations": 0.6275351047515869
#     },
#     "organization": {
#         "Before": 0.29260414838790894,
#         "law.": 0.533740758895874,
#         "municipality": 0.5550092458724976
#     },
#     "penalty": {
#         "9": 0.3510003685951233,
#         "for": 0.4355059862136841,
#         "fails": 0.4532957673072815
#     }
# }
# epoch=02, iteration=00000, loss=0.621197, loss_mean=0.624504
# epoch=02, iteration=00500, loss=0.810711, loss_mean=0.607534
# epoch=02, iteration=01000, loss=0.543378, loss_mean=0.582597
# epoch=02, iteration=01500, loss=0.683631, loss_mean=0.678445
# epoch=02, iteration=02000, loss=0.610673, loss_mean=0.562132
# epoch=02, iteration=02500, loss=0.596826, loss_mean=0.575009
# epoch=02, iteration=03000, loss=0.591325, loss_mean=0.557573
# epoch=02, iteration=03500, loss=0.414496, loss_mean=0.542810
# epoch=02, iteration=04000, loss=0.567565, loss_mean=0.532266
# epoch=02, iteration=04500, loss=0.632869, loss_mean=0.540013
# epoch=02, iteration=05000, loss=0.688010, loss_mean=0.545155
# epoch=02, iteration=05500, loss=0.868488, loss_mean=0.563555
# epoch=02, iteration=06000, loss=0.828676, loss_mean=0.500233
# {
#     "person": {
#         "considers": 0.5631929636001587,
#         "assistance": 0.5950753688812256,
#         "in": 0.6082937717437744
#     },
#     "accessibility": {
#         "considerations": 0.39412611722946167,
#         "otherwise": 0.5859628915786743,
#         "provide": 0.5965662002563477
#     },
#     "organization": {
#         "Before": 0.24206674098968506,
#         "municipality": 0.48185062408447266,
#         "mental": 0.5771411657333374
#     },
#     "penalty": {
#         "9": 0.36454761028289795,
#         "for": 0.3926381468772888,
#         "mail": 0.4567564129829407
#     }
# }
# epoch=03, iteration=00000, loss=0.690078, loss_mean=0.493018
# epoch=03, iteration=00500, loss=0.428672, loss_mean=0.539281
# epoch=03, iteration=01000, loss=1.137581, loss_mean=0.538034
# epoch=03, iteration=01500, loss=0.040993, loss_mean=0.475521
# epoch=03, iteration=02000, loss=0.228377, loss_mean=0.528070
# epoch=03, iteration=02500, loss=0.457975, loss_mean=0.400062
# epoch=03, iteration=03000, loss=0.121844, loss_mean=0.430640
# epoch=03, iteration=03500, loss=0.595286, loss_mean=0.559805
# epoch=03, iteration=04000, loss=0.471944, loss_mean=0.519093
# epoch=03, iteration=04500, loss=0.196681, loss_mean=0.510466
# epoch=03, iteration=05000, loss=0.284371, loss_mean=0.451190
# epoch=03, iteration=05500, loss=0.335876, loss_mean=0.433373
# epoch=03, iteration=06000, loss=0.162348, loss_mean=0.618104
# {
#     "person": {
#         "Part": 0.43883246183395386,
#         "in": 0.6082918643951416,
#         "considers": 0.6127884387969971
#     },
#     "accessibility": {
#         "considerations": 0.3678637742996216,
#         "provide": 0.520255982875824,
#         "(c)": 0.6213576793670654
#     },
#     "organization": {
#         "Before": 0.18843525648117065,
#         "municipality": 0.447157084941864,
#         "mental": 0.5054826736450195
#     },
#     "penalty": {
#         "occupant.": 0.38638758659362793,
#         "fails": 0.41054683923721313,
#         "visual": 0.41202908754348755
#     }
# }
# epoch=04, iteration=00000, loss=0.293120, loss_mean=0.484279
# epoch=04, iteration=00500, loss=0.277312, loss_mean=0.379212
# epoch=04, iteration=01000, loss=0.194559, loss_mean=0.334619
# epoch=04, iteration=01500, loss=0.102448, loss_mean=0.380586
# epoch=04, iteration=02000, loss=0.377808, loss_mean=0.486651
# epoch=04, iteration=02500, loss=1.037869, loss_mean=0.506589
# epoch=04, iteration=03000, loss=0.158494, loss_mean=0.479409
# epoch=04, iteration=03500, loss=0.210021, loss_mean=0.343449
# epoch=04, iteration=04000, loss=0.312705, loss_mean=0.409141
# epoch=04, iteration=04500, loss=0.770770, loss_mean=0.423078
# epoch=04, iteration=05000, loss=0.139810, loss_mean=0.288984
# epoch=04, iteration=05500, loss=0.000190, loss_mean=0.493648
# epoch=04, iteration=06000, loss=0.739790, loss_mean=0.687522
# {
#     "person": {
#         "Part": 0.43679529428482056,
#         "public": 0.5966997146606445,
#         "in": 0.6023861765861511
#     },
#     "accessibility": {
#         "considerations": 0.3373600244522095,
#         "prescribed,": 0.5282222032546997,
#         "provide": 0.537087082862854
#     },
#     "organization": {
#         "Before": 0.19728589057922363,
#         "(\u201cnorme": 0.4522959589958191,
#         "municipality": 0.473338782787323
#     },
#     "penalty": {
#         "fails": 0.2915768623352051,
#         "occupant.": 0.37897932529449463,
#         "(c),": 0.39974015951156616
#     }
# }
# epoch=05, iteration=00000, loss=0.122922, loss_mean=0.279947
# epoch=05, iteration=00500, loss=0.277341, loss_mean=0.383134
# epoch=05, iteration=01000, loss=0.146632, loss_mean=0.308788
# epoch=05, iteration=01500, loss=0.030279, loss_mean=0.621138
# epoch=05, iteration=02000, loss=0.128180, loss_mean=0.628539
# epoch=05, iteration=02500, loss=0.027252, loss_mean=0.265231
# epoch=05, iteration=03000, loss=0.219878, loss_mean=0.602469
# epoch=05, iteration=03500, loss=0.221124, loss_mean=0.317867
# epoch=05, iteration=04000, loss=0.088166, loss_mean=0.400567
# epoch=05, iteration=04500, loss=0.001177, loss_mean=0.266671
# epoch=05, iteration=05000, loss=0.000031, loss_mean=0.306140
# epoch=05, iteration=05500, loss=0.002415, loss_mean=0.295721
# epoch=05, iteration=06000, loss=1.808026, loss_mean=0.538188
# {
#     "person": {
#         "Part": 0.4234686493873596,
#         "public": 0.6075958013534546,
#         "in": 0.6099005937576294
#     },
#     "accessibility": {
#         "considerations": 0.40499913692474365,
#         "provide": 0.5107948780059814,
#         "January": 0.5726466178894043
#     },
#     "organization": {
#         "Before": 0.21543633937835693,
#         "(\u201cnorme": 0.460554301738739,
#         "standard.": 0.47847163677215576
#     },
#     "penalty": {
#         "fails": 0.2605098485946655,
#         "visual": 0.36156052350997925,
#         "(c),": 0.40657252073287964
#     }
# }
# epoch=06, iteration=00000, loss=0.051433, loss_mean=0.359057
# epoch=06, iteration=00500, loss=0.590584, loss_mean=0.432151
# epoch=06, iteration=01000, loss=0.000170, loss_mean=0.498539
# epoch=06, iteration=01500, loss=0.728206, loss_mean=0.278176
# epoch=06, iteration=02000, loss=0.375568, loss_mean=0.530880
# epoch=06, iteration=02500, loss=0.007154, loss_mean=0.538896
# epoch=06, iteration=03000, loss=0.019734, loss_mean=0.359440
# epoch=06, iteration=03500, loss=1.034331, loss_mean=0.480516
# epoch=06, iteration=04000, loss=0.087314, loss_mean=0.578175
# epoch=06, iteration=04500, loss=0.000000, loss_mean=0.367623
# epoch=06, iteration=05000, loss=0.000254, loss_mean=0.556320
# epoch=06, iteration=05500, loss=0.153971, loss_mean=0.612589
# epoch=06, iteration=06000, loss=0.047226, loss_mean=0.473934
# {
#     "person": {
#         "Part": 0.49537819623947144,
#         "public": 0.5920565128326416,
#         "inspector": 0.6108193397521973
#     },
#     "accessibility": {
#         "considerations": 0.3986448645591736,
#         "provide": 0.5150956511497498,
#         "January": 0.5480515956878662
#     },
#     "organization": {
#         "Before": 0.2201443314552307,
#         "(\u201cnorme": 0.4375529885292053,
#         "prevents": 0.4520806670188904
#     },
#     "penalty": {
#         "fails": 0.244226336479187,
#         "visual": 0.3614460825920105,
#         "industries": 0.3726658821105957
#     }
# }
# epoch=07, iteration=00000, loss=0.126077, loss_mean=0.554174
# epoch=07, iteration=00500, loss=0.060768, loss_mean=0.539235
# epoch=07, iteration=01000, loss=0.000000, loss_mean=0.409205
# epoch=07, iteration=01500, loss=0.000228, loss_mean=0.252740
# epoch=07, iteration=02000, loss=0.125475, loss_mean=0.395474
# epoch=07, iteration=02500, loss=0.007682, loss_mean=0.168958
# epoch=07, iteration=03000, loss=0.004608, loss_mean=0.549498
# epoch=07, iteration=03500, loss=0.000111, loss_mean=0.259210
# epoch=07, iteration=04000, loss=0.000000, loss_mean=0.342370
# epoch=07, iteration=04500, loss=0.012655, loss_mean=0.288397
# epoch=07, iteration=05000, loss=0.000000, loss_mean=0.601288
# epoch=07, iteration=05500, loss=0.057431, loss_mean=0.433103
# epoch=07, iteration=06000, loss=0.000006, loss_mean=0.381139
# {
#     "person": {
#         "Part": 0.486833393573761,
#         "public": 0.5780279040336609,
#         "inspector": 0.5980952978134155
#     },
#     "accessibility": {
#         "considerations": 0.3831774592399597,
#         "provide": 0.4799826145172119,
#         "January": 0.5524488687515259
#     },
#     "organization": {
#         "Before": 0.24400317668914795,
#         "(\u201cnorme": 0.40068215131759644,
#         "illness": 0.428313672542572
#     },
#     "penalty": {
#         "fails": 0.25508594512939453,
#         "(c),": 0.31373023986816406,
#         "industries": 0.35917532444000244
#     }
# }
# epoch=08, iteration=00000, loss=0.002341, loss_mean=0.328166
# epoch=08, iteration=00500, loss=0.000725, loss_mean=0.282166
# epoch=08, iteration=01000, loss=0.000023, loss_mean=0.576530
# epoch=08, iteration=01500, loss=0.000014, loss_mean=0.799968
# epoch=08, iteration=02000, loss=0.000884, loss_mean=0.616746
# epoch=08, iteration=02500, loss=0.074562, loss_mean=0.535510
# epoch=08, iteration=03000, loss=0.221886, loss_mean=0.282504
# epoch=08, iteration=03500, loss=0.000001, loss_mean=0.255943
# epoch=08, iteration=04000, loss=0.017550, loss_mean=0.360572
# epoch=08, iteration=04500, loss=0.001971, loss_mean=0.258106
# epoch=08, iteration=05000, loss=0.007987, loss_mean=0.656522
# epoch=08, iteration=05500, loss=0.128391, loss_mean=0.382850
# epoch=08, iteration=06000, loss=0.000032, loss_mean=0.277675
# {
#     "person": {
#         "Part": 0.4868548512458801,
#         "inspector": 0.579177975654602,
#         "public": 0.582754373550415
#     },
#     "accessibility": {
#         "considerations": 0.42272400856018066,
#         "provide": 0.5137202739715576,
#         "or": 0.6012902855873108
#     },
#     "organization": {
#         "Before": 0.2664138674736023,
#         "(\u201cnorme": 0.40841591358184814,
#         "No": 0.4425516724586487
#     },
#     "penalty": {
#         "fails": 0.27019810676574707,
#         "(c),": 0.29168379306793213,
#         "industries": 0.36045563220977783
#     }
# }
# epoch=09, iteration=00000, loss=0.000006, loss_mean=0.519375
# epoch=09, iteration=00500, loss=0.142235, loss_mean=0.449418
# epoch=09, iteration=01000, loss=0.000354, loss_mean=0.201749
# epoch=09, iteration=01500, loss=0.030069, loss_mean=0.538846
# epoch=09, iteration=02000, loss=0.000002, loss_mean=0.285670
# epoch=09, iteration=02500, loss=0.000826, loss_mean=0.239677
# epoch=09, iteration=03000, loss=0.026061, loss_mean=0.609749
# epoch=09, iteration=03500, loss=0.003348, loss_mean=0.424936
# epoch=09, iteration=04000, loss=0.058856, loss_mean=0.531993
# epoch=09, iteration=04500, loss=1.191257, loss_mean=0.227156
# epoch=09, iteration=05000, loss=0.014186, loss_mean=0.527990
# epoch=09, iteration=05500, loss=0.081344, loss_mean=0.471772
# epoch=09, iteration=06000, loss=0.000000, loss_mean=0.559896
# {
#     "person": {
#         "Part": 0.5150851011276245,
#         "public": 0.5902514457702637,
#         "being": 0.5979686975479126
#     },
#     "accessibility": {
#         "considerations": 0.4330671429634094,
#         "provide": 0.5136714577674866,
#         "January": 0.5383156538009644
#     },
#     "organization": {
#         "Before": 0.3008779287338257,
#         "No": 0.38254886865615845,
#         "(\u201cnorme": 0.4123123288154602
#     },
#     "penalty": {
#         "fails": 0.2700122594833374,
#         "(c),": 0.2888021469116211,
#         "industries": 0.38476336002349854
#     }
# }

# %% [markdown]
# # inspect results

# %%
query_results = query_neighbors_in_embedding(
    w=embedding.get_weights()[0],
    words=['person', 'accessibility', 'organization', 'penalty'],
    n_neighbors=10)

print(json.dumps(query_results, indent=4))
# Out:
# {
#     "person": {
#         "Part": 0.5150851011276245,
#         "public": 0.5902514457702637,
#         "being": 0.5979686975479126,
#         "inspector": 0.6020374298095703,
#         "characteristic": 0.6627432107925415,
#         "in": 0.6642177104949951,
#         "If": 0.668149471282959,
#         "authorize": 0.7104040384292603,
#         "Governor": 0.7125017642974854,
#         "meet": 0.7143247127532959
#     },
#     "accessibility": {
#         "considerations": 0.4330671429634094,
#         "provide": 0.5136714577674866,
#         "January": 0.5383156538009644,
#         "or": 0.6363843679428101,
#         "organizations.": 0.640643298625946,
#         "means": 0.6532360315322876,
#         "long-term": 0.6566188335418701,
#         "request.": 0.667556643486023,
#         "(c)": 0.6737946271896362,
#         "partnership": 0.6789298057556152
#     },
#     "organization": {
#         "Before": 0.3008779287338257,
#         "No": 0.38254886865615845,
#         "(\u201cnorme": 0.4123123288154602,
#         "illness": 0.416986346244812,
#         "prevents": 0.4715460538864136,
#         "standard.": 0.49525153636932373,
#         "engaged": 0.5239207744598389,
#         "(\u201corganisation\u201d)": 0.536963939666748,
#         "claimed": 0.5567674040794373,
#         "five": 0.5594199895858765
#     },
#     "penalty": {
#         "fails": 0.2700122594833374,
#         "(c),": 0.2888021469116211,
#         "industries": 0.38476336002349854,
#         "visual": 0.3898959755897522,
#         "mellitus,": 0.4252200126647949,
#         "Acts": 0.42839276790618896,
#         "signed,": 0.46415531635284424,
#         "organizations;": 0.46633291244506836,
#         "mail": 0.48581063747406006,
#         "caused": 0.4879069924354553
#     }
# }

# %%
def find_closest_word_of_all_words():
    query_results = query_neighbors_in_embedding(
        w=embedding.get_weights()[0],
        words=list(dictionary.keys()),
        n_neighbors=1)
    for word, neighbor_dict in query_results.items():
        closest, dist = neighbor_dict.popitem()
        print(f"{word:<16s} {closest:<16s} {dist:}")
    return


find_closest_word_of_all_words()
# Out:
# UNK              appointment,     0.6278156042098999
# the              removes          0.2819681167602539
# or               order            0.42129451036453247
# of               address;         0.37689435482025146
# to               necessary,       0.25748997926712036
# a                produced         0.2608456015586853
# in               order            0.4595080018043518
# and              2025.            0.37236034870147705
# under            17,              0.27207159996032715
# with             fall             0.33263182640075684
# person           Part             0.5150851011276245
# an               ministers        0.3656773567199707
# may              system           0.1742832064628601
# for              amputation,      0.20030367374420166
# this             take             0.30370408296585083
# that             economy          0.2827756404876709
# accessibility    considerations   0.4330671429634094
# be               “disability”     0.41974538564682007
# shall            whole,           0.2818509340286255
# any              produced         0.493587851524353
# by               Such             0.24497085809707642
# is               proceeding       0.2894691824913025
# order            or               0.42129451036453247
# subsection       d’accessibilité”) 0.4592025876045227
# Minister         (“ministre”)     0.28679192066192627
# other            facsimile        0.27732765674591064
# organization     Before           0.3008779287338257
# section          exercised        0.23340660333633423
# as               by,              0.33919721841812134
# Act              disorder,        0.1985875368118286
# director         where            0.3855133652687073
# persons          if               0.5695500373840332
# on               report           0.5336916446685791
# standards        deemed           0.4692407250404358
# The              filing           0.38647687435150146
# such             authenticate     0.2686852812767029
# standard         for,             0.22092288732528687
# time             bearing          0.47858327627182007
# A                Upon             0.3592737913131714
# development      municipality,    0.2514016628265381
# which            identify,        0.35258376598358154
# made             Citizenship      0.3271837830543518
# committee        organization,    0.38459688425064087
# specified        what             0.4722849726676941
# report           submit           0.490306556224823
# it               so,              0.3920271396636963
# within           password,        0.189816415309906
# organizations    “Tribunal”       0.32757776975631714
# proposed         committee:       0.39423298835754395
# Council          commission,      0.4817688465118408
# An               carry            0.4370953440666199
# requirements     measures,        0.3241671919822693
# inspector        An               0.4853937029838562
# Tribunal         combination      0.3585721254348755
# respect          peace            0.38695430755615234
# make             require          0.47952955961227417
# information      (“Tribunal”)     0.31504011154174805
# public           storage,         0.322678804397583
# has              authority        0.5681214332580566
# regulation       deadlines        0.3138188123703003
# more             prevent          0.38659417629241943
# purposes         policy           0.271173357963562
# date             “accessibility   0.4064238667488098
# are              Minister,        0.39346808195114136
# after            fully            0.33039379119873047
# (1)              made             0.5010460615158081
# who              preparing        0.3051019310951233
# administrative   (3),             0.26552534103393555
# considers        and              0.5041064023971558
# all              conditions       0.24261951446533203
# provide          Saturday,        0.43457847833633423
# force            advisable.       0.4108999967575073
# necessary        or               0.5250731706619263
# required         filed            0.3510506749153137
# day              part;            0.38186365365982056
# reports          without          0.5586756467819214
# not              signature”       0.3898245692253113
# penalty          fails            0.2700122594833374
# means            facilities;      0.4988465905189514
# different        date             0.45594412088394165
# part             visual           0.3143245577812195
# out              wheelchair       0.45212990045547485
# pay              enforcement      0.37257683277130127
# at               include          0.3669843077659607
# into             economy          0.5871511697769165
# period           both             0.38151437044143677
# if               peace            0.5133662819862366
# place            Minister,        0.40093958377838135
# notice           considering      0.4105989933013916
# one              time.            0.49886006116867065
# regulations      on               0.5518041849136353
# appeal           Representatives  0.33939963579177856
# Lieutenant       tribunal         0.4533465504646301
# Governor         containing       0.477983295917511
# warrant          section.         0.4096779227256775
# economy          that             0.2827756404876709
# from             signed,          0.4196370244026184
# Section          with             0.4688396453857422
# class            additional       0.3865128755569458
# subject          time             0.5543761253356934
# than             required.        0.5233001708984375
# measures,        policies,        0.30394697189331055
# practices        time-frames      0.2781103849411011
# clause           respect          0.5472214221954346
# terms            used             0.3201291561126709
# may,             blindness        0.4846286177635193
# available        revise           0.28412383794784546
# comply           agreement,       0.5469470024108887
# provided         power            0.34764403104782104
# premises         define           0.2782602310180664
# Act,             approved         0.5332424640655518
# her              or               0.47729355096817017
# including        daylight         0.5345890522003174
# Amendments       This             0.2778930068016052
# (d/m/y)          prevent;         0.21605288982391357
# shall,           developmental    0.20470130443572998
# classes          Recognizing      0.26055997610092163
# referred         premises;        0.31524574756622314
# each             identifies       0.42167752981185913
# accordance       session          0.4574083089828491
# implementation   for              0.4957066774368286
# matters          prevention       0.38402223587036133
# regulations.     obtained         0.30866414308547974
# buildings,       characteristic   0.26351213455200195
# before           Directorate      0.49943971633911133
# disability       foregoing,       0.4247717261314392
# his              produce          0.46789002418518066
# established      standards        0.5584847927093506
# Act;             they             0.2558095455169678
# sector           under            0.3097653388977051
# policies,        measures,        0.30394697189331055
# members          believe          0.3664977550506592
# review           standards.       0.39431822299957275
# document         incurred         0.35245245695114136
# (4)              subject-matter   0.4827578067779541
# council          technical        0.28745561838150024
# disabilities     provide,         0.42829233407974243
# structures       dog              0.4837307333946228
# without          reports          0.5586756467819214
# Act.             practices        0.46754103899002075
# reference        aspects          0.31534498929977417
# whether          name             0.305717408657074
# reason           designated       0.47397178411483765
# If               examine          0.42555153369903564
# inspection       goods,           0.4041815996170044
# record           speech           0.22934764623641968
# case             policies         0.16290253400802612
# respecting       agreement,       0.3836720585823059
# prescribing      comprehensive    0.5290365219116211
# ;                orders           0.4691997766494751
# applies          subject-matter   0.3465923070907593
# apply            2006.            0.3337463140487671
# their            instead          0.25770658254623413
# days             contravention    0.29505687952041626
# modifications    complies         0.4793089032173157
# Minister,        are              0.39346808195114136
# (1),             good             0.3278687596321106
# filed            attributes,      0.2876594662666321
# reasonable       there            0.35383111238479614
# order,           provision        0.32350051403045654
# agreement        take             0.4558808207511902
# service          various          0.34689998626708984
# governing        inspection,      0.3362104892730713
# prescribe        order            0.5355939865112305
# and,             paid;            0.38612377643585205
# hearing          timely           0.22590380907058716
# require          time-frames      0.32418543100357056
# application      following        0.46778392791748047
# industry,        Immigration      0.48403048515319824
# relating         director,        0.27484679222106934
# must             made.            0.48327547311782837
# amount           containing       0.4051656723022461
# site             drawings         0.28307169675827026
# (3)              economic         0.28717267513275146
# Within           years            0.4648092985153198
# submit           established.     0.4656144380569458
# making           relating         0.31212329864501953
# comments         account,         0.3440738916397095
# (5)              public.          0.4313550591468811
# extend           exercise         0.494076132774353
# accommodate      plans            0.33399611711502075
# appropriate.     having           0.32932478189468384
# appoint          advise           0.4572194814682007
# relevant         first            0.11983054876327515
# do               annual           0.6143865585327148
# offence          tribunal         0.37948930263519287
# goods,           inspection       0.4041815996170044
# sectors          dog              0.38876980543136597
# corporation      (“prescrit”)     0.33154964447021484
# every            employed         0.3428117036819458
# Assembly         written          0.3729013204574585
# building,        tribunals        0.4355260729789734
# include          at               0.3669843077659607
# set              device           0.27006441354751587
# named            appeal           0.49509865045547485
# responsible      requiring        0.417919397354126
# process          10,000           0.32234227657318115
# establish        10.              0.4799402356147766
# committees       classes          0.3332729935646057
# advisable.       force            0.4108999967575073
# circumstances    offices          0.28755664825439453
# no               consent          0.29505813121795654
# years            entered          0.43467479944229126
# produce          his              0.46789002418518066
# upon             remedial         0.2886080741882324
# enter            obtained         0.3911324739456177
# document,        believes         0.290630042552948
# thing            Despite          0.6212044954299927
# provision        penalties        0.29727625846862793
# requiring        responsible      0.417919397354126
# advisory         question         0.29344069957733154
# purpose          Ontario,         0.36775875091552734
# Ontario          daylight         0.541729211807251
# standards.       experts          0.3411431312561035
# barrier,         A                0.5595090389251709
# appointed        Minister         0.3125939965248108
# received         Omitted          0.34089046716690063
# whom             attribute,       0.4181554913520813
# prescribed       regulations,     0.3467947840690613
# unless           upon             0.43604809045791626
# establishing     place            0.4340721368789673
# provides         inspector,       0.32497721910476685
# structure        next             0.24519699811935425
# having           appropriate.     0.32932478189468384
# standard.        including,       0.32840609550476074
# described        bodily           0.3901624083518982
# those            powers           0.3499490022659302
# its              payment          0.39302074909210205
# develop          after            0.34526634216308594
# Each             fee              0.3545519709587097
# consult          Speaker          0.36965411901474
# intended         disorder,        0.35905343294143677
# committee.       training         0.42368441820144653
# (6),             notice,          0.4751909375190735
# posting          Subsection       0.3562912344932556
# government       includes,        0.39235830307006836
# internet         (“organisation”) 0.38724637031555176
# (2),             hearing          0.36705052852630615
# (2)              recommend        0.430844247341156
# target           giving           0.29589372873306274
# receiving        10               0.3554384708404541
# advisable        Legislative      0.3350030779838562
# (10)             not,             0.3824349045753479
# request          disabilities.    0.3829224705696106
# director,        relating         0.27484679222106934
# officer          requires         0.2878950834274292
# requirement      revise           0.21193838119506836
# carrying         using            0.3902188539505005
# determining      overseeing       0.20411914587020874
# power            provided         0.34764403104782104
# section.         first            0.3600260019302368
# Subsections      following        0.3776533603668213
# organizations;   corporation,     0.3605154752731323
# inform           holds            0.37386906147003174
# order;           standards;       0.4842105507850647
# 21               which            0.3682767152786255
# powers           “director”       0.23738950490951538
# filing           The              0.38647687435150146
# advise           barriers         0.216144859790802
# duty             practices        0.3855932950973511
# notice,          barriers         0.3394652009010315
# against          hours            0.38831162452697754
# services,        agreement.       0.41382157802581787
# facilities,      services,        0.5079759359359741
# Government       regulation,      0.45472055673599243
# In               consider         0.3465215563774109
# disability,      expenses         0.5050466656684875
# physical         developed        0.3436087965965271
# limiting         determined       0.4744299054145813
# generality       10,000           0.33588898181915283
# designated       conduct          0.19238096475601196
# otherwise        organizations.   0.22570866346359253
# Legislative      advisable        0.3350030779838562
# undertaking      disabilities,    0.3494551181793213
# same             only             0.41209423542022705
# identified       and              0.4329221844673157
# things           good             0.2763214111328125
# create           apply.           0.38784247636795044
# number           prepare          0.44293212890625
# industries,      “regulations”    0.33404481410980225
# further          To               0.23101162910461426
# particular       time.            0.36607420444488525
# following        Subsections      0.3776533603668213
# have             force.           0.34226322174072266
# Accessibility    association,     0.20007961988449097
# specify          society          0.593192458152771
# After            29               0.4087187647819519
# them             provide.         0.35872286558151245
# Minister.        responsibilities 0.4917207956314087
# nature           (“règlements”)   0.2946571707725525
# committee’s      whom             0.5155519247055054
# was              identity         0.392136812210083
# prepare          believe          0.3316367268562317
# No               organization     0.38254886865615845
# policies         case             0.16290253400802612
# Upon             A                0.3592737913131714
# preparation      three            0.3535177707672119
# form             three            0.22659248113632202
# approved         mental           0.30261945724487305
# format           Directorate      0.17970365285873413
# contain          carrying         0.3974602222442627
# electronic       barriers;        0.42989450693130493
# 14               Amendments       0.4356819987297058
# At               member           0.4092966914176941
# being            any              0.5080567598342896
# warrant,         limited          0.4814276695251465
# there            reasonable       0.35383111238479614
# use              authority        0.4440416693687439
# authorize        document         0.3715798854827881
# warrant.         2025             0.3092729449272156
# assistance       prevention       0.3415030837059021
# both             period           0.38151437044143677
# regulations;     establishment,   0.246209979057312
# contravention    days             0.29505687952041626
# conditions       all              0.24261951446533203
# execution        incurred         0.3289394974708557
# issued           wheelchair       0.40165239572525024
# manner           architectural    0.42333704233169556
# regulation,      Government       0.45472055673599243
# fails            penalty          0.2700122594833374
# 27               41               0.5079008340835571
# submissions      earlier          0.39329224824905396
# hold             inspector,       0.31477099657058716
# exercise         extend           0.494076132774353
# perform          which            0.4450526833534241
# duties           attached         0.3607329726219177
# 33               daily            0.42667919397354126
# (8)              relating         0.38746827840805054
# good             things           0.2763214111328125
# conduct          designated       0.19238096475601196
# comes            who              0.3488847613334656
# municipal        method           0.4988848567008972
# programs         been             0.5725439190864563
# method           whom             0.4474797248840332
# agreement.       Building         0.28651511669158936
# payment          degree           0.3210344910621643
# daily            appliance        0.21325403451919556
# effectiveness    only             0.25581055879592896
# Ontario,         purpose          0.36775875091552734
# enforcing        prevention       0.2800578474998474
# accommodation,   processes        0.2393115758895874
# employment,      council          0.3876921534538269
# January          partnership      0.3010099530220032
# 1,               writing          0.42481476068496704
# impediment,      January          0.45625030994415283
# administration   On               0.23828274011611938
# entity           epilepsy,        0.28903114795684814
# type             achieving        0.3653257489204407
# tribunal         system           0.32731324434280396
# imposed          implementing     0.4722670912742615
# that,            services         0.5115722417831421
# engaged          prevents         0.16563230752944946
# implement        defect           0.3342713713645935
# annual           develop          0.5512110590934753
# 6.               matter           0.39654070138931274
# organizations,   Ontario,         0.3686237335205078
# responsibilities developed        0.41239112615585327
# Standards        disabilities;    0.3395618200302124
# Advisory         periods          0.3259849548339844
# fix              amputation,      0.44711440801620483
# stages           population       0.6195468902587891
# reimbursement    a                0.5275356769561768
# determine        appropriate      0.395740270614624
# relation         decide           0.43852877616882324
# implemented      subject-matter   0.36867988109588623
# appropriate      determine        0.395740270614624
# time-frame       obtained         0.1777978539466858
# first            relevant         0.11983054876327515
# five             offence          0.4358246326446533
# changes          law.             0.3209201693534851
# later            authorized       0.2487245798110962
# adopted          known            0.2393120527267456
# writing,         reviews          0.3741031885147095
# (9)              (6)              0.5276370644569397
# until            prevent          0.41504186391830444
# 9                making           0.43717145919799805
# 45               plan             0.26273930072784424
# advice           achieving        0.25131773948669434
# times            1997;            0.40443068742752075
# statement        enforcing        0.3667334318161011
# organization.    1997;            0.45914584398269653
# he               agreement.       0.43495917320251465
# she              reasons          0.4517814517021179
# personal         circumstances    0.3621883988380432
# used             terms            0.3201291561126709
# Deputy           cause            0.39676690101623535
# appointment      periodic         0.3965069651603699
# 19               inspection       0.5648654699325562
# carry            disorder,        0.412100613117218
# inspection.      2006.            0.30029934644699097
# business         achieve          0.31500208377838135
# or,              relating         0.4945051074028015
# inspection;      (5).             0.2633717656135559
# justice          practice;        0.23879611492156982
# peace            respect          0.38695430755615234
# contravened      (3)              0.35697275400161743
# 30               (a).             0.4006884694099426
# additional       industries,      0.3551415801048279
# false            a                0.33545565605163574
# organization,    Act).            0.287483811378479
# doing            determines.      0.26809757947921753
# so               is               0.506446123123169
# Justice          On               0.3136439323425293
# deemed           available        0.40536177158355713
# concludes        On               0.22268688678741455
# following:       architectural    0.309511661529541
# (4.1).           available        0.35625338554382324
# either           overseeing       0.42819076776504517
# paragraph        all              0.34781593084335327
# 1                disfigurement    0.3369728922843933
# To               further          0.23101162910461426
# (5),             administration   0.3032096028327942
# what             next             0.39692872762680054
# gives            next             0.38998842239379883
# written          Assembly         0.3729013204574585
# alleged          premises.        0.5131415128707886
# made.            January          0.3593630790710449
# 21,              bind             0.28943055868148804
# 25               accommodation;   0.28666144609451294
# Despite          part             0.3841897249221802
# parties          Upon             0.3742997646331787
# interest         they             0.4778746962547302
# municipality     learning         0.3088870644569397
# disabilities.    request          0.3829224705696106
# new              owns             0.3410424590110779
# entered          meeting          0.2686525583267212
# director’s       including        0.5429037809371948
# regulations,     prescribed       0.3467947840690613
# restrictions     format           0.2690661549568176
# person’s         recommendations  0.37363922595977783
# direction        upon             0.35492146015167236
# related          manner           0.4263265132904053
# they             Act;             0.2558095455169678
# accessible       amount,          0.21048343181610107
# undertake        form.            0.30730879306793213
# organization;    various          0.3387705683708191
# failed           tribunals        0.2801642417907715
# given            Sunday           0.47112900018692017
# served           earlier          0.4026384949684143
# next             structure        0.24519699811935425
# Omitted          received         0.34089046716690063
# delivery         “barrier”        0.28537511825561523
# corporation,     organizations;   0.3605154752731323
# apparently       describe         0.2665001153945923
# charge           vary             0.4646339416503906
# office           entered          0.3099558353424072
# not,             paralysis,       0.20971274375915527
# cause            meetings         0.36286795139312744
# guilty           dog              0.33649295568466187
# enforcement      “disability”     0.36730092763900757
# Every            all              0.4296133518218994
# fine             keep             0.35170137882232666
# occurs           ensure           0.49018871784210205
# continues        shall,           0.30015283823013306
# included         place.           0.16243976354599
# fee              Each             0.3545519709587097
# 29               holds            0.3412880301475525
# matter           person,          0.3282613158226013
# amounts          served           0.4034768342971802
# draft            2025             0.2368963360786438
# benefit          agreements       0.29364097118377686
# Ontarians        Act;             0.5405139923095703
# providing        regulations;     0.33514320850372314
# various          organization;    0.3387705683708191
# because          data             0.3633697032928467
# means,           exceed           0.3534581661224365
# degree           payment          0.3210344910621643
# injury,          individual;      0.4151724576950073
# illness          organization     0.416986346244812
# mental           prevents         0.28600209951400757
# using            mail             0.34191298484802246
# benefits         knowledge        0.31924301385879517
# were             Service          0.28700000047683716
# whatever         1997;            0.373992919921875
# Executive        subject-matter   0.3234086036682129
# private          shall            0.303139328956604
# board,           attached         0.4793655276298523
# commission,      Council          0.4817688465118408
# authority        remedial         0.4068688154220581
# trade            Citizenship      0.431519091129303
# appeal.          circumstances    0.2879924178123474
# Nothing          cases,           0.30313974618911743
# obligations      included         0.40194666385650635
# This             Amendments       0.2778930068016052
# name             whether          0.305717408657074
# only             effectiveness    0.25581055879592896
# services         giving           0.3973609209060669
# prescribed.      consent          0.3017094135284424
# define           premises         0.2782602310180664
# consist          Superior         0.3143991231918335
# exclude          dwelling;        0.34051722288131714
# attributes,      filed            0.2876594662666321
# qualities        effectiveness    0.4600064754486084
# characteristics. Act;             0.4442853331565857
# impose           criteria         0.2410752773284912
# identification   dysfunction      0.2684788107872009
# barriers         advise           0.216144859790802
# power,           (d/m/y)          0.4957607388496399
# attribute,       whom             0.4181554913520813
# quality          French           0.2848726511001587
# characteristic   buildings,       0.26351213455200195
# combination      Tribunal         0.3585721254348755
# items,           identifies       0.30151355266571045
# including,       standard.        0.32840609550476074
# employed         every            0.3428117036819458
# revenue;         one              0.5412739515304565
# industry         not              0.5070221424102783
# part;            practice;        0.2434535026550293
# size             qualities        0.549081027507782
# premises.        Subsections      0.49564605951309204
# general          classes          0.30174821615219116
# specific         amputation,      0.41166210174560547
# limited          indicates        0.32604366540908813
# place.           included         0.16243976354599
# achieving        (PIN),           0.17581886053085327
# considered       first            0.29460614919662476
# defining         because          0.4635416865348816
# invite           for              0.5198856592178345
# participate      Nothing          0.34397971630096436
# Representatives  appeal           0.33939963579177856
# apply.           create           0.38784247636795044
# Such             by               0.24497085809707642
# meet             employed         0.46465224027633667
# allowance        legal            0.27043992280960083
# expenses         disability,      0.5050466656684875
# minutes          effect           0.19773560762405396
# long-term        “organization”   0.5763387084007263
# objectives       entity;          0.24108272790908813
# believes         document,        0.290630042552948
# remove           Ontario.         0.2590130567550659
# economic         (3)              0.28717267513275146
# associated       hearing          0.41729122400283813
# implementation;  aspects          0.43241405487060547
# consideration    prescribed.      0.34661006927490234
# reference.       doing            0.39082491397857666
# identifies       items,           0.30151355266571045
# successive       reasonably       0.395355224609375
# previous         Within           0.5286149382591248
# date.            three            0.3658685088157654
# 6                corporation      0.5271009206771851
# developed        physical         0.3436087965965271
# question         advisory         0.29344069957733154
# specify,         reasonable       0.4570325016975403
# another          implementation;  0.44938981533050537
# (c)              benefits         0.6261814832687378
# subsequent       believes         0.4892064929008484
# (b)              holds            0.4220759868621826
# regulation.      based            0.2778667211532593
# progress         organizations    0.37367457151412964
# time.            particular       0.36607420444488525
# file             Recognizing      0.3893418312072754
# been             Acts             0.3538702726364136
# preparing        who              0.3051019310951233
# signature.       information      0.4264081120491028
# signature        establishment,   0.3152453899383545
# complies         the              0.41376829147338867
# complied         29               0.4287024140357971
# applicable       copies           0.37454479932785034
# compliance       aspects          0.3567889928817749
# inspectors       encourage        0.3767651319503784
# issue            Such             0.3189118504524231
# certificate      used             0.5552636384963989
# facsimile        other            0.27732765674591064
# request.         English          0.45744001865386963
# course           co-ordination,   0.23325836658477783
# where            director         0.3855133652687073
# documents        part             0.38588041067123413
# inspect          upon             0.3508150577545166
# during           incurred         0.2583041787147522
# regular          course           0.3895134925842285
# consent          7,               0.23548907041549683
# data             because          0.3633697032928467
# storage,         public           0.322678804397583
# processing       director         0.4066092371940613
# retrieval        1,               0.5481765270233154
# device           set              0.27006441354751587
# system           may              0.1742832064628601
# readable         stage            0.3132389783859253
# form.            undertake        0.30730879306793213
# obtained         time-frame       0.1777978539466858
# special,         knowledge        0.49267756938934326
# expert           believes         0.34037667512893677
# professional     individual,      0.23178249597549438
# knowledge        benefits         0.31924301385879517
# (a)              representatives. 0.37765151262283325
# reasonably       (d/m/y)          0.31371182203292847
# (11)             public           0.46287351846694946
# copy             malformation     0.4447407126426697
# original         inspection,      0.30932867527008057
# ensure           dysfunction      0.3618994355201721
# authorized       later            0.2487245798110962
# circumstances.   bearing          0.5513513684272766
# specifies        premises         0.3135014772415161
# carried          inspection,      0.2344353199005127
# treated          daily            0.25221163034439087
# effect           minutes          0.19773560762405396
# Superior         consist          0.3143991231918335
# Court            remove           0.35457247495651245
# 17,              under            0.27207159996032715
# Subject          Service          0.24185103178024292
# Comply           proceeding       0.24274379014968872
# ordered          Service          0.229142963886261
# encourage        business         0.32874757051467896
# prevent          reviews          0.3145732283592224
# penalty.         removed,         0.40344756841659546
# reasons          Province         0.42255377769470215
# subsections      experts          0.49492424726486206
# (3),             administrative   0.26552534103393555
# done             (4)              0.5067346096038818
# right            committee        0.40335410833358765
# so,              mental           0.31036245822906494
# opportunity      paid;            0.23862993717193604
# take             this             0.30370408296585083
# vary             Crown.           0.32149672508239746
# rescind          case             0.4408602714538574
# tribunals        failed           0.2801642417907715
# panel            giving           0.4323130249977112
# proper           diminishes       0.38999223709106445
# mediation        later            0.294360876083374
# population       dysfunction      0.3742685914039612
# less             organization;    0.3471124768257141
# 10,000           process          0.32234227657318115
# continue         dates            0.3865400552749634
# force.           have             0.34226322174072266
# majority         accommodation,   0.4865238666534424
# seek             Superior         0.32651716470718384
# timely           hearing          0.22590380907058716
# plans            accommodate      0.33399611711502075
# drawings         site             0.28307169675827026
# 41               appliance        0.24501633644104004
# Planning         effectiveness    0.49178969860076904
# functions        relating         0.2759997844696045
# premises,        record           0.34505194425582886
# enters           throughout       0.3280160427093506
# facilities       requirement      0.3539765477180481
# 2006.            inspection.      0.30029934644699097
# instead          their            0.25770658254623413
# own              appeal.          0.437869131565094
# joint            money            0.27793312072753906
# (6)              exceed           0.3940693140029907
# appointment.     sign             0.41455239057540894
# authorization    amount,          0.51275634765625
# orders           participate      0.4641481041908264
# (5).             inspection;      0.2633717656135559
# proceeding       Comply           0.24274379014968872
# faith            number           0.5391433238983154
# known            adopted          0.2393120527267456
# English          designated       0.3264039158821106
# French           quality          0.2848726511001587
# determines.      doing            0.26809757947921753
# prepared         may              0.3272210955619812
# subject-matter   Executive        0.3234086036682129
# Directorate      format           0.17970365285873413
# employees        agreement,       0.33495044708251953
# Part             Accessibility    0.2585240602493286
# Service          ordered          0.229142963886261
# establishment    Province         0.4128384590148926
# training         by               0.35752034187316895
# material         “organization”   0.31420189142227173
# standards;       constitutes      0.38392961025238037
# content          later            0.45277249813079834
# reports;         document         0.37058013677597046
# accommodation    by               0.29133278131484985
# employment       doing            0.4559457302093506
# provide,         “director”       0.3675798177719116
# disabilities;    Standards        0.3395618200302124
# examine          If               0.42555153369903564
# Acts             (3)              0.3355061411857605
# recommendations  communications   0.2671654224395752
# agreements       benefit          0.29364097118377686
# exceed           means,           0.3534581661224365
# agreement,       employees        0.33495044708251953
# gave             Immigration      0.4846014976501465
# 20               10.              0.35975486040115356
# person,          involvement      0.31549322605133057
# Saturday,        provide          0.43457847833633423
# Sunday           offence          0.3802325129508972
# provisions       agreement,       0.48570048809051514
# Act).            organization,    0.287483811378479
# mail             visual           0.2585768699645996
# receive          execution        0.40151554346084595
# misleading       types            0.3547479510307312
# information;     misleading       0.40675634145736694
# liable           services,        0.525811493396759
# $50,000          prescribed       0.5198676586151123
# occur.           included         0.17002856731414795
# time-frames      practices        0.2781103849411011
# reports,         shall,           0.43776047229766846
# penalties        provision        0.29727625846862793
# paid;            opportunity      0.23862993717193604
# constitutes      encourage        0.3555566072463989
# exempting        minutes          0.36470669507980347
# thereof          no               0.3943432569503784
# effective        based            0.2918657064437866
# criteria         impose           0.2410752773284912
# types            misleading       0.3547479510307312
# maximum          vary             0.43648087978363037
# amount,          accessible       0.21048343181610107
# penalties,       partnership      0.43161022663116455
# money            joint            0.27793312072753906
# laid             In               0.6209665536880493
# session          readable         0.35044920444488525
# session.         who              0.404516339302063
# consultation     premises         0.46598219871520996
# comprehensive    attached         0.4761298894882202
# three            form             0.22659248113632202
# Recognizing      classes          0.26055997610092163
# history          include          0.4742037057876587
# discrimination   order            0.5488301515579224
# by,              as               0.33919721841812134
# developing,      effectiveness    0.5575399398803711
# implementing     imposed          0.4722670912742615
# achieve          business         0.31500208377838135
# 2025;            amount,          0.4647899866104126
# involvement      person,          0.31549322605133057
# disabilities,    legal            0.21716183423995972
# representatives  owns             0.2931720018386841
# industries       record           0.2498464584350586
# “accessibility   date             0.4064238667488098
# standard”        standard         0.40009069442749023
# 6;               certifying       0.4025599956512451
# (“norme          agreement,       0.3602414131164551
# d’accessibilité”) received         0.4353838562965393
# “barrier”        delivery         0.28537511825561523
# anything         provided         0.4772237539291382
# prevents         engaged          0.16563230752944946
# fully            after            0.33039379119873047
# participating    employment       0.5250442028045654
# aspects          reference        0.31534498929977417
# society          specify          0.593192458152771
# architectural    following:       0.309511661529541
# communications   recommendations  0.2671654224395752
# attitudinal      or               0.5089943408966064
# technological    fall             0.4655638337135315
# policy           purposes         0.271173357963562
# practice;        justice          0.23879611492156982
# (“obstacle”)     Safety           0.3743342161178589
# “director”       powers           0.23738950490951538
# 30;              inform           0.4668906331062317
# (“directeur”)    minutes          0.5614858865737915
# “disability”     enforcement      0.36730092763900757
# infirmity,       10;              0.32927852869033813
# malformation     allowance        0.3104301691055298
# disfigurement    experts          0.26832789182662964
# caused           spoken           0.2248833179473877
# bodily           described        0.3901624083518982
# birth            brain            0.44248825311660767
# defect           implement        0.3342713713645935
# foregoing,       adopted          0.3110646605491638
# includes         section.         0.45846331119537354
# diabetes         Ontario,         0.44356638193130493
# mellitus,        penalty          0.4252200126647949
# epilepsy,        entity           0.28903114795684814
# brain            birth            0.44248825311660767
# paralysis,       not,             0.20971274375915527
# amputation,      for              0.20030367374420166
# lack             foregoing,       0.32264846563339233
# co-ordination,   course           0.23325836658477783
# blindness        lack             0.34122949838638306
# visual           mail             0.2585768699645996
# deafness         attributes,      0.4054722189903259
# muteness         bind             0.5399714112281799
# speech           record           0.22934764623641968
# reliance         Nothing          0.3048504590988159
# guide            upon             0.44104188680648804
# dog              Subject          0.31586503982543945
# animal           guide            0.48658227920532227
# wheelchair       issued           0.40165239572525024
# remedial         upon             0.2886080741882324
# appliance        daily            0.21325403451919556
# device,          met              0.2009924054145813
# condition        regulations.     0.3524531126022339
# impairment       enter            0.47389620542526245
# developmental    shall,           0.20470130443572998
# learning         municipality     0.3088870644569397
# dysfunction      copies           0.23350989818572998
# processes        accommodation,   0.2393115758895874
# involved         overseeing       0.27069026231765747
# understanding    reference,       0.5767367482185364
# symbols          within           0.19859975576400757
# spoken           caused           0.2248833179473877
# language,        are              0.4532046318054199
# disorder,        Act              0.1985875368118286
# injury           password,        0.3174592852592468
# claimed          (2)              0.4715113043785095
# insurance        hours            0.3496916890144348
# plan             45               0.26273930072784424
# Workplace        format           0.4447983503341675
# Safety           (“obstacle”)     0.3743342161178589
# Insurance        agreement,       0.5466310977935791
# 1997;            whatever         0.373992919921875
# (“handicap”)     provide.         0.5456449389457703
# “Minister”       inspection,      0.3878854513168335
# Citizenship      effective        0.31186461448669434
# Immigration      regulations;     0.30948346853256226
# member           exceed           0.36395692825317383
# assigned         29               0.3757858872413635
# (“ministre”)     Minister         0.28679192066192627
# “organization”   material         0.31420189142227173
# includes,        considering      0.3130694627761841
# agency           (2),             0.5393397808074951
# agency,          panel            0.5342503786087036
# authority,       develop          0.5636424422264099
# municipality,    development      0.2514016628265381
# association,     Accessibility    0.20007961988449097
# partnership      January          0.3010099530220032
# union,           case             0.3997674584388733
# entity;          objectives       0.24108272790908813
# (“organisation”) Before           0.21738791465759277
# “prescribed”     issued           0.5333787202835083
# regulation;      force.           0.4617704153060913
# (“prescrit”)     corporation      0.33154964447021484
# “regulations”    industries,      0.33404481410980225
# context          caused           0.42573487758636475
# indicates        limited          0.32604366540908813
# requires         officer          0.2878950834274292
# otherwise;       proposed         0.46054214239120483
# (“règlements”)   nature           0.2946571707725525
# “Tribunal”       organizations    0.32757776975631714
# 26               hearing          0.4628788232803345
# (“Tribunal”)     information      0.31504011154174805
# diminishes       retain,          0.2723524570465088
# way              not              0.42519527673721313
# legal            disabilities,    0.21716183423995972
# law.             10.              0.2713969945907593
# Province         and,             0.4030734896659851
# Ontario.         remove           0.2590130567550659
# binds            daily            0.21387261152267456
# Crown.           vary             0.32149672508239746
# describe         On               0.24836194515228271
# applies.         constitutes      0.40756136178970337
# facilities;      penalty          0.4942857027053833
# employs          mediation        0.36551976203918457
# Ontario;         English          0.47666841745376587
# offers           under            0.4343569874763489
# accommodation;   25               0.28666144609451294
# owns             representatives  0.2931720018386841
# occupies         offers           0.5348466634750366
# premises;        referred         0.31524574756622314
# business,        disability,      0.580586314201355
# activity         achieving        0.30225682258605957
# meets            Amendments       0.3427516222000122
# Speaker          demand           0.328039288520813
# Building         agreement.       0.28651511669158936
# offices          circumstances    0.28755664825439453
# fall             with             0.33263182640075684
# jurisdiction     further          0.48038142919540405
# removal          approved         0.4068780541419983
# structures,      provisions       0.5821992754936218
# prescribed,      members          0.4340261220932007
# prevention       enforcing        0.2800578474998474
# erection         specify.         0.4996386766433716
# barriers;        reasonable       0.3915753960609436
# periods          Advisory         0.3259849548339844
# overseeing       determining      0.20411914587020874
# As               plans            0.36667877435684204
# 7,               consent          0.23548907041549683
# adoption         mental           0.37224525213241577
# for,             standard         0.22092288732528687
# developing       mail             0.31043630838394165
# specify;         Comply           0.4160540699958801
# (a).             30               0.4006884694099426
# Before           (“organisation”) 0.21738791465759277
# ministers        an               0.3656773567199707
# organizations.   otherwise        0.22570866346359253
# entities         biometric        0.5001679062843323
# committee:       proposed         0.39423298835754395
# Persons          17,              0.35015714168548584
# representatives. individual;      0.26404881477355957
# ministries       municipality     0.41403037309646606
# consider         In               0.3465215563774109
# deadlines        regulation       0.3138188123703003
# throughout       enters           0.3280160427093506
# process.         doing            0.38931208848953247
# attendance       report.          0.4485786557197571
# meetings         cause            0.36286795139312744
# incurred         during           0.2583041787147522
# determines;      complies         0.5545352101325989
# paid.            hours.           0.592177152633667
# fixing           believes         0.3753224015235901
# keep             fine             0.35170137882232666
# meeting          entered          0.2686525583267212
# holds            29               0.3412880301475525
# provide.         them             0.35872286558151245
# Promptly         tribunal         0.43302851915359497
# establishment,   engaged          0.2206103801727295
# 8                accommodation;   0.4760487675666809
# identifying      penalties,       0.44337528944015503
# should           6;               0.5228931903839111
# 2025.            and              0.37236034870147705
# taking           range            0.4210946559906006
# account,         comments         0.3440738916397095
# range            signed,          0.3822856545448303
# address;         of               0.37689435482025146
# identify,        in,              0.2766481041908264
# prevent;         (d/m/y)          0.21605288982391357
# technical        council          0.28745561838150024
# considerations   accessibility    0.4330671429634094
# enable           further          0.3828863501548767
# according        practices        0.3673035502433777
# rules:           to               0.32415497303009033
# stage            readable         0.3132389783859253
# established.     (2);             0.41947484016418457
# dates            continue         0.3865400552749634
# reference,       Subsection       0.2570708394050598
# 10.              law.             0.2713969945907593
# considering      includes,        0.3130694627761841
# 10,              appropriate.     0.3920913338661194
# 90               further          0.2865806221961975
# decide           system,          0.3118930459022522
# recommend        municipality,    0.412265419960022
# whole,           shall            0.2818509340286255
# modifications.   matter           0.4314955472946167
# On               concludes        0.22268688678741455
# decision         (“organisation”) 0.4075413942337036
# (7),             periodic         0.2913297414779663
# inform,          Speaker          0.37627261877059937
# decision.        incurred         0.34217214584350586
# earlier          submissions      0.39329224824905396
# re-examine       electronically   0.439441978931427
# determined       extracts;        0.28367745876312256
# (2);             established.     0.41947484016418457
# required,        21,              0.30122196674346924
# revise           requirement      0.21193838119506836
# 2025             draft            0.2368963360786438
# containing       hours            0.35810720920562744
# additions        such             0.4926717281341553
# existing         draft            0.39448875188827515
# deems            were             0.356808602809906
# 10;              infirmity,       0.32927852869033813
# based            regulation.      0.2778667211532593
# 10               receiving        0.3554384708404541
# Subsection       reference,       0.2570708394050598
# reviews          prevent          0.3145732283592224
# (c),             fails            0.287769079208374
# periodic         (7),             0.2913297414779663
# retain,          diminishes       0.2723524570465088
# experts          disfigurement    0.26832789182662964
# annually         powers           0.5734145641326904
# specify.         part             0.413027286529541
# public.          involvement      0.3308578133583069
# electronically   agreement.       0.30621808767318726
# certifying       section          0.27515190839767456
# accurate         been             0.38467925786972046
# signed,          range            0.3822856545448303
# individual,      professional     0.23178249597549438
# individual;      representatives. 0.26404881477355957
# cases,           Nothing          0.30313974618911743
# senior           as               0.39378881454467773
# bind             21,              0.28943055868148804
# sign             appointment.     0.41455239057540894
# met              device,          0.2009924054145813
# “electronic      cases,           0.46452033519744873
# signature”       not              0.3898245692253113
# (PIN),           achieving        0.17581886053085327
# password,        within           0.189816415309906
# biometric        document,        0.39837926626205444
# creates          identity         0.40374141931533813
# adopts           agreements       0.41521984338760376
# authenticate     such             0.2686852812767029
# identity         was              0.392136812210083
# in,              identify,        0.2766481041908264
# attached         duties           0.3607329726219177
# report.          accompanied      0.3422906994819641
# submitted        existing         0.404682993888855
# bearing          under            0.29321515560150146
# with.            dates            0.4555971026420593
# inspection,      carried          0.2344353199005127
# lands            periods          0.482909619808197
# believe          prepare          0.3316367268562317
# exercised        section          0.23340660333633423
# place’s          Minister         0.3994429111480713
# hours            insurance        0.3496916890144348
# does             At               0.4157429337501526
# hours,           and,             0.4503231644630432
# daylight         20               0.50527423620224
# hours.           administration   0.32896941900253296
# dwelling         revise           0.5316417217254639
# occupant.        include          0.4864533543586731
# entering         preparation      0.36521977186203003
# giving           target           0.29589372873306274
# receipt          premises;        0.5619776248931885
# it,              determined       0.38465601205825806
# copies           dysfunction      0.23350989818572998
# extracts;        determined       0.28367745876312256
# present          municipal        0.5415396690368652
# producing        apply            0.38941580057144165
# appointment,     signature        0.4070214033126831
# dwelling;        exclude          0.34051722288131714
# demand           Speaker          0.328039288520813
# produced         a                0.2608456015586853
# writing          10               0.4006745219230652
# required.        organizations,   0.38533854484558105
# accompanied      report.          0.3422906994819641
# inspector,       hold             0.31477099657058716
# necessary,       to               0.25748997926712036
# system,          decide           0.3118930459022522
# removes          the              0.2819681167602539
# removed,         penalty.         0.40344756841659546
# request,         population       0.4260904788970947
